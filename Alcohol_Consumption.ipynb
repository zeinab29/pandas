# %% [markdown]
# <a href="https://colab.research.google.com/github/zeinab29/pandas/blob/main/Alcohol_Consumption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ex - GroupBy

# %% [markdown]
# ### Introduction:
#
# GroupBy can be summarized as Split-Apply-Combine.
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# Check out this [Diagram](http://i.imgur.com/yjNkiwL.png)
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv"

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
drinks = pd.read_csv(url,sep=',')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
df = pd.DataFrame(drinks)

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
avg_beer_by_continent = df.groupby("continent")["beer_servings"].mean().sort_values(ascending=False)
avg_beer_by_continent
# Out:
# continent
# EU    193.777778
# SA    175.083333
# OC     89.687500
# AF     61.471698
# AS     37.045455
# Name: beer_servings, dtype: float64

# %%
top_continent = avg_beer_by_continent.idxmax()
print("Continent with highest average beer consumption per capita:", top_continent)
# Out:
# Continent with highest average beer consumption per capita: EU

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
wine_stat = df.groupby("continent")["wine_servings"].agg(['mean', 'std', 'max', 'min'])
wine_stat
# Out:
#                  mean        std  max  min
# continent
# AF          16.264151  38.846419  233    0
# AS           9.068182  21.667034  123    0
# EU         142.222222  97.421738  370    0
# OC          35.625000  64.555790  212    0
# SA          62.416667  88.620189  221    1

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
alcohol_mean = df.groupby("continent").mean(numeric_only=True)

# %%
alcohol_mean
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
alcohol_median = df.groupby("continent").median(numeric_only=True)
alcohol_median
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75
# SA                                 6.85

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame

# %%
numeric_cols = df.select_dtypes(include='number').columns
alcohol_cons = df.groupby("continent")[numeric_cols].agg(["mean","min","max"])

# %%
alcohol_cons
# Out:
#           beer_servings          spirit_servings          wine_servings      \
#                    mean min  max            mean min  max          mean min
# continent
# AF            61.471698   0  376       16.339623   0  152     16.264151   0
# AS            37.045455   0  247       60.840909   0  326      9.068182   0
# EU           193.777778   0  361      132.555556   0  373    142.222222   0
# OC            89.687500   0  306       58.437500   0  254     35.625000   0
# SA           175.083333  93  333      114.750000  25  302     62.416667   1
#
#                total_litres_of_pure_alcohol
#            max                         mean  min   max
# continent
# AF         233                     3.007547  0.0   9.1
# AS         123                     2.170455  0.0  11.5
# EU         370                     8.617778  0.0  14.4
# OC         212                     3.381250  0.0  10.4
# SA         221                     6.308333  3.8   8.3
